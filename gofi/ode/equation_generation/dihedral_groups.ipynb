# %% [markdown]
# # Results for dihedral groups

# %%
from loss import FpGroup_L_irr, FpGroup_L_rel, FpGroup_matrices

# %% [markdown]
# ### 2 dimensional representations:
# Lets define Dihedral group $D_{2n} = <s, r \mid s^2 = r^n = rsrs = 1>$.

# %%
from sympy.combinatorics.fp_groups import FpGroup
from sympy.combinatorics.free_groups import free_group
import sympy

dim = 2
def D2n(n: int):
    F, s, r = free_group("s, r")
    relators = [s**2, r**n, r * s * r * s]
    return FpGroup(F, relators)

n = 3
group = D2n(n)
s = sympy.Symbol("s")
r = sympy.Symbol("r")

# %% [markdown]
# Parse the equation for $\mathcal L$:

# %%
L_r = FpGroup_L_rel(group, dim)

# %%
L_irr = FpGroup_L_irr(group, dim)

# %%
L = L_r + L_irr

# %% [markdown]
# Collect parameters of the model (loss) - for every group element $z = x + iy$, ž $x$ and $y$ are two parameters of the model.

# %%
from loss import matrix_element_symbol
# params:
matrices = FpGroup_matrices(group, dim)

matrices[s]
# Out:
# Matrix([
# [{x_s}_{0;0} + I*{y_s}_{0;0}, {x_s}_{0;1} + I*{y_s}_{0;1}],
# [{x_s}_{1;0} + I*{y_s}_{1;0}, {x_s}_{1;1} + I*{y_s}_{1;1}]])

# %%
params = [matrix_element_symbol(name, generator, row, column) 
          for name in ["x", "y"] 
          for generator in [ s, r]
          for row in range(2)
          for column in range(2)]
print(f"Number of parameters is {len(params)}.")
# Out:
# Number of parameters is 16.

# %% [markdown]
# Get equations for $\frac{d \mathcal L}{d p}$, where $p$ is a parameter

# %%
# calculates dL/dp for every param
derivatives = {
    param : sympy.diff(L, param) for param in params
}

# %% [markdown]
# Convert equations to python functons

# %%
from tqdm import tqdm
lambda_derivatives = {}
for param in tqdm(params, total=len(params)):
    lambda_derivatives[param] = sympy.lambdify(tuple(params), derivatives[param] )
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]

# %% [markdown]
# ### Example of one trajectory
# We will plot just $tr(\rho(r)$  and $tr(\rho(s)$

# %%
#print(params)
#lambda_derivatives[params[0]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 #print(params)
# ----> 2 lambda_derivatives[params[0]]
#
# TypeError: 'function' object is not subscriptable

# %%
# example of one trajectory

from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import numpy as np

# sollve d(x,y)/dt = -gradL
def neg_grad(t, z):
    '''
    Returns a vector `(-L_p (z) for p in params)`.
    '''
    return [-lambda_derivatives[param](z) for param in params]




# Plot the solution in 2D (y vs x)
plt.figure(figsize=(16, 16))
ax = plt.gca()
ax.set_xlim([-2, 2])
ax.set_ylim([-2, 2])

# initial values - set every param to 1
p0 = [1. for _ in params]
#time frame 
t_max =1

# solve 
solution = solve_ivp(neg_grad, (0, t_max), p0)


cmap = plt.get_cmap('viridis')
norm = plt.Normalize(vmin=0, vmax=t_max)  # Normalize based on time range
# plot initial step
plt.plot(solution.y[0][0], solution.y[1][0], 'ro', label='Initial point', markersize=3)


# Plot the solution in 2D (y vs x) with color changing over time
for i in range(len(solution.t) - 1):
    plt.plot(solution.y[0][i:i+2], solution.y[1][i:i+2], color=cmap(norm(solution.t[i])), lw=2)#, marker= '>')
#plt.plot(solution.y[0], solution.y[1], label='Gradient flow trajectory')



plt.xlabel('x(t)')
plt.ylabel('y(t)')
plt.title('Trajectory of gradient flows ') 
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 29
#      26 t_max =1
#      28 # solve
# ---> 29 solution = solve_ivp(neg_grad, (0, t_max), p0)
#      32 cmap = plt.get_cmap('viridis')
#      33 norm = plt.Normalize(vmin=0, vmax=t_max)  # Normalize based on time range
#
# File ~/Documents/fmf/magistrska-naloga/magisterij/venv/lib/python3.12/site-packages/scipy/integrate/_ivp/ivp.py:621, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     618 if method in METHODS:
#     619     method = METHODS[method]
# --> 621 solver = method(fun, t0, y0, tf, vectorized=vectorized, **options)
#     623 if t_eval is None:
#     624     ts = [t0]
#
# File ~/Documents/fmf/magistrska-naloga/magisterij/venv/lib/python3.12/site-packages/scipy/integrate/_ivp/rk.py:94, in RungeKutta.__init__(self, fun, t0, y0, t_bound, max_step, rtol, atol, vectorized, first_step, **extraneous)
#      92 self.max_step = validate_max_step(max_step)
#      93 self.rtol, self.atol = validate_tol(rtol, atol, self.n)
# ---> 94 self.f = self.fun(self.t, self.y)
#      95 if first_step is None:
#      96     self.h_abs = select_initial_step(
#      97         self.fun, self.t, self.y, t_bound, max_step, self.f, self.direction,
#      98         self.error_estimator_order, self.rtol, self.atol)
#
# File ~/Documents/fmf/magistrska-naloga/magisterij/venv/lib/python3.12/site-packages/scipy/integrate/_ivp/base.py:154, in OdeSolver.__init__.<locals>.fun(t, y)
#     152 def fun(t, y):
#     153     self.nfev += 1
# --> 154     return self.fun_single(t, y)
#
# File ~/Documents/fmf/magistrska-naloga/magisterij/venv/lib/python3.12/site-packages/scipy/integrate/_ivp/base.py:23, in check_arguments.<locals>.fun_wrapped(t, y)
#      22 def fun_wrapped(t, y):
# ---> 23     return np.asarray(fun(t, y), dtype=dtype)
#
# Cell In[31], line 12, in neg_grad(t, z)
#       8 def neg_grad(t, z):
#       9     '''
#      10     Returns a vector `(-L_p (z) for p in params)`.
#      11     '''
# ---> 12     return [-lambda_derivatives[param](z) for param in params]
#
# TypeError: 'function' object is not subscriptable
